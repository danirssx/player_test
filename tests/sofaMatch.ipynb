# %%
import pandas as pd

# %%
### Import the module of SofaScore
import sys
sys.path.append('../')
from classes.sofaScore import sofaScore

# %%
dataSofa = sofaScore()

# %%
### Grab the match:
data_match = dataSofa.get_match('https://www.sofascore.com/stlouis-city-la-galaxy/nabsdgnd#11352816')
# Out:
# 11352816

# %%
### Shots:
data_match['Shotmap']
# Out:
#                player     shortName shotType  isHome    bodyPart        xG  \
# 0      Dejan Joveljić   D. Joveljić     miss    True        head  0.014179
# 1       Douglas Costa      D. Costa    block    True   left-foot  0.019572
# 2          Tyler Boyd       T. Boyd     save    True  right-foot  0.051084
# 3      Dejan Joveljić   D. Joveljić     save    True        head  0.082671
# 4         João Klauss     J. Klauss     goal   False  right-foot  0.263871
# 5          Riqui Puig       R. Puig    block    True  right-foot  0.024550
# 6      Dejan Joveljić   D. Joveljić     save    True  right-foot  0.037893
# 7          Tyler Boyd       T. Boyd     save    True  right-foot  0.080718
# 8        Oriol Rosell     O. Rosell    block    True  right-foot  0.027593
# 9          Tyler Boyd       T. Boyd    block    True   left-foot  0.031019
# 10         Riqui Puig       R. Puig     goal    True  right-foot  0.788400
# ...
