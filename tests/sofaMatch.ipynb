# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
### Import the module of SofaScore
import sys
sys.path.append('../')
from classes.sofaScore import sofaScore

# %%
dataSofa = sofaScore()

# %%
### Grab the match:
data_match = dataSofa.get_match('https://www.sofascore.com/netherlands-ireland/TTbsfUb#10752488')
# Out:
# 10752488

# %%
graph = data_match['Graph']

graph.plot(y='periodCount', x='periodTime')
# Out:
# 1
