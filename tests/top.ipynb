# %%
# Importing Libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os

# %%
import sys
sys.path.append('../')
from classes.fbref import FBRef

# %% [markdown]
# ## Here we will compare the top teams in LaLiga and Premier League:
# In LaLiga we will grab Real Madrid, Barcelona and Atlético Madrid.

# %%
data = FBRef()

# %% [markdown]
# ## We will group each team in a Panda dataset:

# %%
#### Get access to the file with the data: 
current_directory = os.getcwd()
hdf5_file_path = os.path.join(current_directory, '../matches_data/laliga_j2.h5')

#### Store the result to possibly work with that:
store = pd.HDFStore(hdf5_file_path)
laliga = store['laliga_j2']
store.close()

# %% [markdown]
# ## Premier League

# %%
#### Get access: 
current_directory_premier = os.getcwd()
hdf5_file_path_premier = os.path.join(current_directory_premier, '../matches_data/premier_j2.h5')

#### store it
store_premier = pd.HDFStore(hdf5_file_path_premier)
premier = store_premier['Jornada 2']

premier['Jornada 2']['Liverpool']['Shots']['Shots']['Home']
# Out:
#    Minute                  Player      Squad    xG  PSxG     Outcome  \
# 0       6         Virgil van Dijk  Liverpool  0.09   NaN    Woodwork
# 1      13  Trent Alexander-Arnold  Liverpool  0.03  0.11       Saved
# 2      18               Luis Díaz  Liverpool  0.04   NaN     Blocked
# 3      18               Luis Díaz  Liverpool  0.11   NaN     Blocked
# 4      18      Dominik Szoboszlai  Liverpool  0.04   NaN     Blocked
# 5      19              Cody Gakpo  Liverpool  0.02   NaN  Off Target
# 6      28               Luis Díaz  Liverpool  0.27  0.49        Goal
# 7      34           Mohamed Salah  Liverpool  0.10   NaN  Off Target
# 8      36     Mohamed Salah (pen)  Liverpool  0.79  0.97       Saved
# 9      36           Mohamed Salah  Liverpool  0.75  0.94        Goal
# 10     45  Trent Alexander-Arnold  Liverpool  0.07  0.15       Saved
# 11   45+1         Virgil van Dijk  Liverpool  0.10   NaN  Off Target
# 12   45+3      Dominik Szoboszlai  Liverpool  0.06   NaN     Blocked
# 13   45+3         Ibrahima Konaté  Liverpool  0.05   NaN  Off Target
# 14     46  Trent Alexander-Arnold  Liverpool  0.04   NaN     Blocked
# 15     50              Diogo Jota  Liverpool  0.06   NaN  Off Target
# 16     51              Diogo Jota  Liverpool  0.09   NaN  Off Target
# 17     53           Mohamed Salah  Liverpool  0.10  0.50       Saved
# 18     54              Cody Gakpo  Liverpool  0.08   NaN     Blocked
# 19     54              Cody Gakpo  Liverpool  0.13   NaN     Blocked
# 20     58              Diogo Jota  Liverpool  0.09   NaN     Blocked
# 21     62      Dominik Szoboszlai  Liverpool  0.03  0.17       Saved
# 22     62              Diogo Jota  Liverpool  0.34  0.99        Goal
# 23     67              Diogo Jota  Liverpool  0.10  0.07       Saved
# 24     72         Virgil van Dijk  Liverpool  0.02  0.49       Saved
# 25     83           Mohamed Salah  Liverpool  0.08   NaN  Off Target
#
#     Distance   Body Part      Notes                  Player        Event  \
# 0        9.0        Head        NaN        Andrew Robertson  Pass (Dead)
# 1       15.0  Right Foot        NaN  Trent Alexander-Arnold      Take-On
# 2       15.0  Right Foot        NaN  Trent Alexander-Arnold  Pass (Live)
# 3       20.0  Right Foot        NaN               Luis Díaz         Shot
# 4       13.0   Left Foot        NaN               Luis Díaz         Shot
# 5       24.0  Right Foot        NaN           Mohamed Salah  Pass (Live)
# 6        9.0  Right Foot     Volley              Diogo Jota      Take-On
# 7       21.0   Left Foot        NaN              Diogo Jota  Pass (Live)
# 8       13.0   Left Foot        NaN      Dominik Szoboszlai       Fouled
# 9        5.0   Left Foot     Volley           Mohamed Salah         Shot
# 10      15.0   Left Foot        NaN              Cody Gakpo  Pass (Live)
# 11       8.0        Head        NaN        Andrew Robertson  Pass (Dead)
# 12      20.0  Right Foot        NaN              Diogo Jota  Pass (Live)
# 13      10.0        Head        NaN  Trent Alexander-Arnold  Pass (Dead)
# 14      26.0  Right Foot        NaN      Dominik Szoboszlai  Pass (Dead)
# 15      11.0        Head        NaN        Andrew Robertson  Pass (Dead)
# 16      25.0  Right Foot        NaN                     NaN          NaN
# 17       8.0   Left Foot        NaN                     NaN          NaN
# 18      16.0   Left Foot        NaN               Luis Díaz  Pass (Live)
# 19      16.0  Right Foot        NaN              Cody Gakpo         Shot
# 20      10.0   Left Foot        NaN               Luis Díaz  Pass (Live)
# 21      24.0  Right Foot  Deflected  Trent Alexander-Arnold  Pass (Live)
# 22       4.0   Left Foot        NaN      Dominik Szoboszlai         Shot
# 23       7.0   Left Foot        NaN              Diogo Jota      Take-On
# 24      53.0  Right Foot  Free kick               Luis Díaz       Fouled
# 25      22.0   Left Foot        NaN         Virgil van Dijk  Pass (Live)
#
#                     Player        Event
# 0                      NaN          NaN
# 1            Mohamed Salah  Pass (Live)
# 2       Dominik Szoboszlai  Pass (Live)
# 3                      NaN          NaN
# 4                      NaN          NaN
# 5      Alexis Mac Allister  Pass (Live)
# 6   Trent Alexander-Arnold  Pass (Live)
# 7               Cody Gakpo  Pass (Live)
# 8   Trent Alexander-Arnold  Pass (Live)
# 9                      NaN          NaN
# 10      Dominik Szoboszlai  Pass (Live)
# 11  Trent Alexander-Arnold         Shot
# 12      Dominik Szoboszlai  Pass (Live)
# 13      Dominik Szoboszlai         Shot
# 14                     NaN          NaN
# 15                     NaN          NaN
# 16                     NaN          NaN
# 17                     NaN          NaN
# 18     Alexis Mac Allister  Pass (Live)
# 19                     NaN          NaN
# 20               Luis Díaz      Take-On
# 21               Luis Díaz  Pass (Live)
# 22                     NaN          NaN
# 23             Wataru Endo       Tackle
# 24         Ibrahima Konaté  Pass (Live)
# 25               Luis Díaz  Pass (Live)
