# %%
import pandas as pd

# %%
url_name = 'https://www.sofascore.com/colombia-venezuela/xUbsvWb#11518409'

import requests

headers = {
    'authority': 'api.sofascore.com',
    'accept': '*/*',
    'accept-language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'cache-control': 'max-age=0',
    'if-none-match': 'W/"e22c025662"',
    'origin': 'https://www.sofascore.com',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Microsoft Edge";v="116"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.62',
}

response = requests.get('https://api.sofascore.com/api/v1/event/11518409/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
headers['If-Modified-Since'] = 'Mon, 28 Aug 2023 00:00:00 GMT'

# %% [markdown]
# ### SHOTMAP

# %%
response = requests.get('https://api.sofascore.com/api/v1/event/11518409/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
shots = response.json()

# %%
df = pd.DataFrame(shots)
testing = pd.DataFrame(df['shotmap'][1])
# test_two = pd.DataFrame(testing['draw']['start'])

print('addedTime' in testing.columns)
testing
# Out:
# True
#                     player  isHome shotType situation  playerCoordinates  \
# name       Jorge Carrascal    True     miss  assisted                NaN
# slug       jorge-carrascal    True     miss  assisted                NaN
# shortName     J. Carrascal    True     miss  assisted                NaN
# position                 F    True     miss  assisted                NaN
# userCount             2200    True     miss  assisted                NaN
# id                  590392    True     miss  assisted                NaN
# x                      NaN    True     miss  assisted               23.1
# y                      NaN    True     miss  assisted               64.6
# z                      NaN    True     miss  assisted                0.0
# start                  NaN    True     miss  assisted                NaN
# end                    NaN    True     miss  assisted                NaN
# goal                   NaN    True     miss  assisted                NaN
#
#             bodyPart goalMouthLocation  goalMouthCoordinates       id  time  \
# name       left-foot         high-left                   NaN  2190216    90
# slug       left-foot         high-left                   NaN  2190216    90
# shortName  left-foot         high-left                   NaN  2190216    90
# position   left-foot         high-left                   NaN  2190216    90
# userCount  left-foot         high-left                   NaN  2190216    90
# id         left-foot         high-left                   NaN  2190216    90
# x          left-foot         high-left                   0.0  2190216    90
# y          left-foot         high-left                  72.9  2190216    90
# z          left-foot         high-left                  87.5  2190216    90
# start      left-foot         high-left                   NaN  2190216    90
# end        left-foot         high-left                   NaN  2190216    90
# goal       left-foot         high-left                   NaN  2190216    90
#
#            addedTime  timeSeconds                    draw  reversedPeriodTime  \
# name               3         5568                     NaN                   1
# slug               3         5568                     NaN                   1
# shortName          3         5568                     NaN                   1
# position           3         5568                     NaN                   1
# userCount          3         5568                     NaN                   1
# id                 3         5568                     NaN                   1
# x                  3         5568                     NaN                   1
# y                  3         5568                     NaN                   1
# z                  3         5568                     NaN                   1
# start              3         5568  {'x': 64.6, 'y': 23.1}                   1
# end                3         5568     {'x': 27.1, 'y': 0}                   1
# goal               3         5568  {'x': 27.1, 'y': 12.5}                   1
#
#            reversedPeriodTimeSeconds incidentType
# name                             732         shot
# slug                             732         shot
# shortName                        732         shot
# position                         732         shot
# userCount                        732         shot
# id                               732         shot
# x                                732         shot
# y                                732         shot
# z                                732         shot
# start                            732         shot
# end                              732         shot
# goal                             732         shot

# %%
### Iterate shit
data = {
    'player': [],
    'shortName': [],
    'shotType': [],
    'isHome': [],
    'bodyPart': [],
    'xG': [],
    'minute': [],
    'addedTime': [],
    'start': [],
    'block': [],
    'end': [],
    'goal': [],
    'position': [],
}

# %%
# player_one = pd.DataFrame(df['shotmap'][0])
# player_name = player_one['player']['name']
# player_name

#### OVERALL
for i in range(len(df)-1): 
    ### Systematic data:
    ## NAMES
    player_one = pd.DataFrame(df['shotmap'][i])
    # Appending data
    data['player'].append(player_one['player']['name'])
    ### Short name
    data['shortName'].append(player_one['player']['shortName'])
    ### Position
    data['position'].append(player_one['player']['position'])
    ### isHome
    data['isHome'].append(player_one['isHome']['name'])
    ## ShotType
    data['shotType'].append(player_one['shotType']['name'])
    ### bodyPart
    data['bodyPart'].append(player_one['bodyPart']['name'])
    ### xG
    if 'xg' in player_one.columns: 
        data['xG'].append(player_one['xg']['name'])
    else:
        data['xG'].append(pd.NA)
    ### Minute
    data['minute'].append(player_one['time']['name'])
    ### Added-time
    if 'addedTime' in player_one.columns:
        data['addedTime'].append(player_one['addedTime']['name'])
    else:
         data['addedTime'].append(pd.NA)

    #### Scrap inside of it
    # Start
    start = pd.DataFrame(player_one['draw']['start'], index=[0])
    data['start'].append(start)

    # block
    if 'block' in player_one['draw'].index:
        block = pd.DataFrame(player_one['draw']['block'], index=[0])
        data['block'].append(block)
    else:
         data['block'].append(pd.NA)

    # endpoint
    endPoint = pd.DataFrame(player_one['draw']['end'], index=[0])
    data['end'].append(endPoint)

    # goal 
    goal = pd.DataFrame(player_one['draw']['goal'], index=[0])
    data['goal'].append(goal)

# %%
df_shots = pd.DataFrame(data).iloc[::-1].reset_index(drop=True)
df_shots[df_shots['isHome'] == False]
# Out:
#                  player     shortName shotType  isHome    bodyPart    xG  \
# 2             Luis Díaz       L. Díaz    block    True  right-foot  <NA>
# 5          Mateus Uribe      M. Uribe     save    True  right-foot  <NA>
# 6       Jefferson Lerma      J. Lerma    block    True  right-foot  <NA>
# 7   Rafael Santos Borré   R. S. Borré     goal    True        head  <NA>
# 8          Mateus Uribe      M. Uribe    block    True  right-foot  <NA>
# 9             Luis Díaz       L. Díaz     save    True   left-foot  <NA>
# 10      Jorge Carrascal  J. Carrascal     miss    True  right-foot  <NA>
# 12            Luis Díaz       L. Díaz     miss    True        head  <NA>
# 13      Jefferson Lerma      J. Lerma     miss    True        head  <NA>
# 14            Luis Díaz       L. Díaz     miss    True  right-foot  <NA>
# 15           Jhon Durán      J. Durán     miss    True        head  <NA>
# 16           Jhon Durán      J. Durán     save    True   left-foot  <NA>
# 17      Jorge Carrascal  J. Carrascal     miss    True   left-foot  <NA>
#
#     minute addedTime                        start  \
# 2       24      <NA>        x     y
# 0  45.1  22.8
# 5       45         3        x     y
# 0  50.5  17.7
# 6       45         3        x     y
# 0  52.5  19.6
# 7       46      <NA>          x    y
# 0  47.8  7.6
# 8       52      <NA>            x    y
# 0  65  6.6
# 9       55      <NA>          x    y
# 0  26.7  4.8
# 10      64      <NA>        x     y
# 0  38.9  12.9
# 12      79      <NA>        x     y
# 0  38.2  10.5
# 13      81      <NA>              x  y
# 0  47.5  8
# 14      86      <NA>          x     y
# 0  32  16.2
# 15      90         1            x    y
# 0  54  5.1
# 16      90         1          x    y
# 0  75.6  8.3
# 17      90         3        x     y
# 0  64.6  23.1
#
#                           block                    end  \
# 2         x     y
# 0  45.8  20.2        x  y
# 0  51.6  0
# 5           x    y
# 0  51.4  0.6        x  y
# 0  53.9  0
# 6         x     y
# 0  52.2  16.7        x  y
# 0  50.3  0
# 7                          <NA>        x  y
# 0  51.8  0
# 8             x    y
# 0  56  2.2        x  y
# 0  51.6  0
# 9               x  y
# 0  48.4  0        x  y
# 0  53.3  0
# 10                         <NA>        x  y
# 0  40.5  0
# 12                         <NA>        x  y
# 0  38.5  0
# 13          x    y
# 0  66.1  2.3        x  y
# 0  75.6  0
# 14                         <NA>        x  y
# 0  63.2  0
# 15                         <NA>        x  y
# 0  52.1  0
# 16          x    y
# 0  54.2  0.9        x  y
# 0  48.9  0
# 17                         <NA>        x  y
# 0  27.1  0
#
#                            goal position
# 2             x   y
# 0  51.6  81        F
# 5         x     y
# 0  53.9  90.5        M
# 6             x   y
# 0  50.3  81        M
# 7         x     y
# 0  51.8  98.1        F
# 8             x   y
# 0  51.6  81        M
# 9         x     y
# 0  53.3  93.7        F
# 10        x     y
# 0  40.5  95.8        F
# 12        x     y
# 0  38.5  94.4        F
# 13        x     y
# 0  75.6  91.7        M
# 14        x     y
# 0  63.2  79.2        F
# 15        x     y
# 0  52.1  34.7        F
# 16        x     y
# 0  48.9  90.5        F
# 17        x     y
# 0  27.1  12.5        F

# %% [markdown]
# ## BEST PLAYERS

# %%
best_players = requests.get('https://api.sofascore.com/api/v1/event/11518409/best-players', headers=headers)

# %%
best_players.status_code
# Out:
# 200

# %%
best_pl = response.json()
df_players = pd.DataFrame(best_pl)

# %%
df_players
# Out:
#                                               shotmap
# 0   {'player': {'name': 'Rómulo Otero', 'slug': 'r...
# 1   {'player': {'name': 'Jorge Carrascal', 'slug':...
# 2   {'player': {'name': 'Jhon Durán', 'firstName':...
# 3   {'player': {'name': 'Jhon Durán', 'firstName':...
# 4   {'player': {'name': 'Luis Díaz', 'slug': 'luis...
# 5   {'player': {'name': 'Jefferson Lerma', 'slug':...
# 6   {'player': {'name': 'Luis Díaz', 'slug': 'luis...
# 7   {'player': {'name': 'Josef Martínez', 'slug': ...
# 8   {'player': {'name': 'Jorge Carrascal', 'slug':...
# 9   {'player': {'name': 'Luis Díaz', 'slug': 'luis...
# 10  {'player': {'name': 'Mateus Uribe', 'slug': 'm...
# 11  {'player': {'name': 'Rafael Santos Borré', 'sl...
# 12  {'player': {'name': 'Jefferson Lerma', 'slug':...
# 13  {'player': {'name': 'Mateus Uribe', 'slug': 'm...
# 14  {'player': {'name': 'Darwin Machís', 'firstNam...
# 15  {'player': {'name': 'Darwin Machís', 'firstNam...
# 16  {'player': {'name': 'Luis Díaz', 'slug': 'luis...
# 17  {'player': {'name': 'Yangel Herrera', 'slug': ...
# 18  {'player': {'name': 'Wilker Ángel', 'slug': 'w...
# 19  {'player': {'name': 'Jefferson Savarino', 'fir...
