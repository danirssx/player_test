# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url_name = 'https://www.sofascore.com/villarreal-barcelona/rgbsugb#11368592'

import requests

headers = {
    'authority': 'api.sofascore.com',
    'accept': '*/*',
    'accept-language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'cache-control': 'max-age=0',
    'if-none-match': 'W/"e22c025662"',
    'origin': 'https://www.sofascore.com',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Microsoft Edge";v="116"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.62',
}

response = requests.get('https://api.sofascore.com/api/v1/event/11368592/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
headers['If-Modified-Since'] = 'Mon, 28 Aug 2023 00:00:00 GMT'

# %% [markdown]
# ### SHOTMAP

# %%
response = requests.get('https://api.sofascore.com/api/v1/event/11368592/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
shots = response.json()

# %%
df = pd.DataFrame(shots)
testing = pd.DataFrame(df['shotmap'][1])
# test_two = pd.DataFrame(testing['draw']['start'])

print('addedTime' in testing.columns)
testing
# Out:
# True
#                       player  isHome shotType situation  playerCoordinates  \
# name       Ben Brereton Díaz    True     miss  assisted                NaN
# firstName                       True     miss  assisted                NaN
# lastName                        True     miss  assisted                NaN
# slug       ben-brereton-diaz    True     miss  assisted                NaN
# shortName   B. Brereton Díaz    True     miss  assisted                NaN
# position                   F    True     miss  assisted                NaN
# userCount               3714    True     miss  assisted                NaN
# id                    867583    True     miss  assisted                NaN
# x                        NaN    True     miss  assisted               23.6
# y                        NaN    True     miss  assisted               32.8
# z                        NaN    True     miss  assisted                0.0
# start                    NaN    True     miss  assisted                NaN
# end                      NaN    True     miss  assisted                NaN
# goal                     NaN    True     miss  assisted                NaN
#
#              bodyPart goalMouthLocation  goalMouthCoordinates        xg  \
# name       right-foot             right                   NaN  0.037187
# firstName  right-foot             right                   NaN  0.037187
# lastName   right-foot             right                   NaN  0.037187
# slug       right-foot             right                   NaN  0.037187
# shortName  right-foot             right                   NaN  0.037187
# position   right-foot             right                   NaN  0.037187
# userCount  right-foot             right                   NaN  0.037187
# id         right-foot             right                   NaN  0.037187
# x          right-foot             right                   0.0  0.037187
# y          right-foot             right                  37.3  0.037187
# z          right-foot             right                  13.9  0.037187
# start      right-foot             right                   NaN  0.037187
# end        right-foot             right                   NaN  0.037187
# goal       right-foot             right                   NaN  0.037187
#
#                 id  time  addedTime  timeSeconds                    draw  \
# name       2171333    90          5         5650                     NaN
# firstName  2171333    90          5         5650                     NaN
# lastName   2171333    90          5         5650                     NaN
# slug       2171333    90          5         5650                     NaN
# shortName  2171333    90          5         5650                     NaN
# position   2171333    90          5         5650                     NaN
# userCount  2171333    90          5         5650                     NaN
# id         2171333    90          5         5650                     NaN
# x          2171333    90          5         5650                     NaN
# y          2171333    90          5         5650                     NaN
# z          2171333    90          5         5650                     NaN
# start      2171333    90          5         5650  {'x': 32.8, 'y': 23.6}
# end        2171333    90          5         5650     {'x': 62.7, 'y': 0}
# goal       2171333    90          5         5650  {'x': 62.7, 'y': 86.1}
#
#            reversedPeriodTime  reversedPeriodTimeSeconds incidentType
# name                        1                        650         shot
# firstName                   1                        650         shot
# lastName                    1                        650         shot
# slug                        1                        650         shot
# shortName                   1                        650         shot
# position                    1                        650         shot
# userCount                   1                        650         shot
# id                          1                        650         shot
# x                           1                        650         shot
# y                           1                        650         shot
# z                           1                        650         shot
# start                       1                        650         shot
# end                         1                        650         shot
# goal                        1                        650         shot

# %%
### Iterate shit
data = {
    'player': [],
    'shortName': [],
    'shotType': [],
    'isHome': [],
    'bodyPart': [],
    'xG': [],
    'minute': [],
    'addedTime': [],
    'start': [],
    'block': [],
    'end': [],
    'goal': [],
    'position': [],
}

# %%
# player_one = pd.DataFrame(df['shotmap'][0])
# player_name = player_one['player']['name']
# player_name

#### OVERALL
for i in range(len(df)-1): 
    ### Systematic data:
    ## NAMES
    player_one = pd.DataFrame(df['shotmap'][i])
    data['player'].append(player_one['player']['name'])
    ### Short name
    data['shortName'].append(player_one['player']['shortName'])
    ### Position
    data['position'].append(player_one['player']['position'])
    ### isHome
    data['isHome'].append(player_one['isHome']['name'])
    ## ShotType
    data['shotType'].append(player_one['shotType']['name'])
    ### bodyPart
    data['bodyPart'].append(player_one['bodyPart']['name'])
    ### xG
    data['xG'].append(player_one['xg']['name'])
    ### Minute
    data['minute'].append(player_one['time']['name'])
    ### Added-time
    if 'addedTime' in player_one.columns:
        data['addedTime'].append(player_one['addedTime']['name'])
    else:
         data['addedTime'].append(pd.NA)

    #### Scrap inside of it
    # Start
    start = pd.DataFrame(player_one['draw']['start'], index=[0])
    data['start'].append(start)

    # block
    if 'block' in player_one['draw'].index:
        block = pd.DataFrame(player_one['draw']['block'], index=[0])
        data['block'].append(block)
    else:
         data['block'].append(pd.NA)

    # endpoint
    endPoint = pd.DataFrame(player_one['draw']['end'], index=[0])
    data['end'].append(endPoint)

    # goal 
    goal = pd.DataFrame(player_one['draw']['goal'], index=[0])
    data['goal'].append(goal)

# %%
df_shots = pd.DataFrame(data).iloc[::-1].reset_index(drop=True)
df_shots
# Out:
#                 player         shortName shotType  isHome    bodyPart  \
# 0      Alejandro Baena          A. Baena    block    True  right-foot
# 1      Alejandro Baena          A. Baena     miss    True  right-foot
# 2        Gerard Moreno         G. Moreno    block    True   left-foot
# 3    Alexander Sørloth        A. Sørloth     save    True   left-foot
# 4                 Gavi              Gavi     goal   False        head
# 5         Lamine Yamal      Lamine Yamal    block   False   left-foot
# 6      Frenkie de Jong        F. de Jong     goal   False  right-foot
# 7   Robert Lewandowski    R. Lewandowski    block   False  right-foot
# 8      Alfonso Pedraza        A. Pedraza     save    True   left-foot
# 9           Juan Foyth          J. Foyth     goal    True        head
# 10       Gerard Moreno         G. Moreno    block    True   left-foot
# 11     Alejandro Baena          A. Baena     save    True  right-foot
# 12      İlkay Gündoğan       İ. Gündoğan     save   False  right-foot
# 13   Alexander Sørloth        A. Sørloth     goal    True   left-foot
# 14         Oriol Romeu          O. Romeu     save   False   left-foot
# 15        Lamine Yamal      Lamine Yamal    block   False   left-foot
# 16         Oriol Romeu          O. Romeu     miss   False   left-foot
# 17     Alejandro Baena          A. Baena     goal    True  right-foot
# 18          Juan Foyth          J. Foyth    block    True  right-foot
# 19        Lamine Yamal      Lamine Yamal     post   False  right-foot
# 20  Robert Lewandowski    R. Lewandowski     save   False  right-foot
# 21       Marcos Alonso         M. Alonso     save   False   left-foot
# 22       Ferran Torres         F. Torres    block   False  right-foot
# 23       Ferran Torres         F. Torres     goal   False   left-foot
# 24        Lamine Yamal      Lamine Yamal     save   False   left-foot
# 25  Robert Lewandowski    R. Lewandowski     goal   False   left-foot
# 26           Ansu Fati           A. Fati    block   False  right-foot
# 27  Robert Lewandowski    R. Lewandowski    block   False   left-foot
# 28           Ansu Fati           A. Fati     miss   False   left-foot
# 29  Robert Lewandowski    R. Lewandowski     save   False  right-foot
# 30        Fermín López          F. López     save   False   left-foot
# 31   Ben Brereton Díaz  B. Brereton Díaz     miss    True  right-foot
# 32        Jorge Cuenca         J. Cuenca     miss    True   left-foot
#
#           xG  minute addedTime                        start  \
# 0   0.043379       4      <NA>        x     y
# 0  29.1  16.6
# 1   0.079010       7      <NA>        x     y
# 0  45.2  16.1
# 2   0.044905       9      <NA>        x     y
# 0  61.2  19.6
# 3   0.378138      10      <NA>            x    y
# 0  38  7.3
# 4   0.265444      12      <NA>          x    y
# 0  41.9  3.8
# 5   0.023341      15      <NA>        x     y
# 0  67.2  21.2
# 6   0.295657      15      <NA>          x     y
# 0  48  13.4
# 7   0.135754      22      <NA>        x     y
# 0  59.4  11.3
# 8   0.083927      25      <NA>          x    y
# 0  29.3  9.8
# 9   0.062883      26      <NA>              x  y
# 0  45.7  8
# 10  0.058904      29      <NA>        x     y
# 0  59.4  15.5
# 11  0.054783      31      <NA>        x     y
# 0  63.9  23.6
# 12  0.022192      38      <NA>        x     y
# 0  52.4  26.4
# 13  0.840181      40      <NA>          x    y
# 0  54.2  3.9
# 14  0.024097      43      <NA>        x     y
# 0  61.6  27.3
# 15  0.073532      45         4          x    y
# 0  60.6  9.9
# 16  0.033011      49      <NA>        x     y
# 0  49.3  19.8
# 17  0.149849      50      <NA>        x     y
# 0  33.4  10.8
# 18  0.012187      54      <NA>          x    y
# 0  76.7  7.5
# 19  0.058494      56      <NA>        x     y
# 0  58.8  13.7
# 20  0.085537      60      <NA>          x     y
# 0  57  17.2
# 21  0.062648      65      <NA>        x     y
# 0  31.6  13.7
# 22  0.074428      68      <NA>        x     y
# 0  52.4  14.1
# 23  0.099094      68      <NA>        x     y
# 0  47.4  10.7
# 24  0.025765      71      <NA>              x   y
# 0  66  16
# 25  0.900230      71      <NA>          x    y
# 0  46.8  4.6
# 26  0.031020      84      <NA>        x     y
# 0  33.8  12.2
# 27  0.076471      84      <NA>        x     y
# 0  43.3  10.4
# 28  0.253111      85      <NA>        x     y
# 0  48.1  11.5
# 29  0.394762      90         1        x     y
# 0  64.7  12.3
# 30  0.062807      90         3        x     y
# 0  51.5  23.2
# 31  0.037187      90         5        x     y
# 0  32.8  23.6
# 32  0.015736      90         6          x    y
# 0  33.4  2.8
#
#                           block                    end  \
# 0         x     y
# 0  36.8  10.9        x  y
# 0  51.4  0
# 1                          <NA>          x  y
# 0  57  0
# 2         x     y
# 0  60.1  17.2        x  y
# 0  52.3  0
# 3           x    y
# 0  43.1  4.4        x  y
# 0  48.7  0
# 4                          <NA>          x  y
# 0  52  0
# 5         x     y
# 0  64.1  17.1        x  y
# 0  51.2  0
# 6                          <NA>        x  y
# 0  46.8  0
# 7           x    y
# 0  57.9  9.8        x  y
# 0  48.3  0
# 8           x    y
# 0  44.8  1.5        x  y
# 0  51.9  0
# 9                          <NA>        x  y
# 0  46.9  0
# 10              x   y
# 0  57  11        x  y
# 0  51.3  0
# 11          x    y
# 0  51.4  1.9        x  y
# 0  46.6  0
# 12          x    y
# 0  50.7  1.5        x  y
# 0  54.4  0
# 13                         <NA>        x  y
# 0  52.5  0
# 14            x    y
# 0  52  1.9        x  y
# 0  53.3  0
# 15          x    y
# 0  58.8  8.1        x  y
# 0  50.8  0
# 16                         <NA>        x  y
# 0  48.4  0
# 17                         <NA>        x  y
# 0  53.9  0
# 18              x  y
# 0  72.4  6        x  y
# 0  54.4  0
# 19                         <NA>        x  y
# 0  55.2  0
# 20          x    y
# 0  51.4  2.4        x  y
# 0  47.5  0
# 21          x    y
# 0  46.9  1.4        x  y
# 0  47.7  0
# 22          x     y
# 0  52  10.9        x  y
# 0  50.6  0
# 23                         <NA>        x  y
# 0  51.1  0
# 24          x    y
# 0  50.7  1.2        x  y
# 0  53.6  0
# 25                         <NA>        x  y
# 0  49.4  0
# 26          x    y
# 0  37.4  9.3        x  y
# 0  48.7  0
# 27          x    y
# 0  44.4  8.4          x  y
# 0  49  0
# 28                         <NA>        x  y
# 0  32.6  0
# 29          x    y
# 0  59.2  7.2        x  y
# 0  52.7  0
# 30          x    y
# 0  50.2  2.4        x  y
# 0  54.5  0
# 31                         <NA>        x  y
# 0  62.7  0
# 32          x    y
# 0  98.2  9.8          x  y
# 0  97  0
#
#                            goal position
# 0             x   y
# 0  51.4  81        M
# 1           x     y
# 0  57  70.8        M
# 2             x   y
# 0  52.3  81        F
# 3         x     y
# 0  48.7  97.5        F
# 4           x     y
# 0  52  85.4        M
# 5             x   y
# 0  51.2  81        F
# 6             x   y
# 0  46.8  93        M
# 7             x   y
# 0  48.3  81        F
# 8         x     y
# 0  51.9  92.4        D
# 9         x     y
# 0  46.9  79.1        D
# 10            x   y
# 0  51.3  81        F
# 11        x     y
# 0  46.6  77.8        M
# 12        x     y
# 0  54.4  90.5        M
# 13        x     y
# 0  52.5  77.2        F
# 14        x     y
# 0  53.3  93.7        M
# 15            x   y
# 0  50.8  81        F
# 16        x     y
# 0  48.4  45.8        M
# 17            x   y
# 0  53.9  81        M
# 18            x   y
# 0  54.4  81        D
# 19        x     y
# 0  55.2  65.8        F
# 20        x     y
# 0  47.5  75.9        F
# 21        x     y
# 0  47.7  98.7        D
# 22            x   y
# 0  50.6  81        F
# 23        x     y
# 0  51.1  82.9        F
# 24        x     y
# 0  53.6  93.7        F
# 25        x     y
# 0  49.4  98.1        F
# 26            x   y
# 0  48.7  81        F
# 27              x   y
# 0  49  81        F
# 28        x     y
# 0  32.6  62.5        F
# 29        x     y
# 0  52.7  84.2        F
# 30        x     y
# 0  54.5  98.1        M
# 31        x     y
# 0  62.7  86.1        F
# 32          x     y
# 0  97  83.3        D

# %% [markdown]
# ## BEST PLAYERS

# %%
best_players = requests.get('https://api.sofascore.com/api/v1/event/11368592/best-players', headers=headers)

# %%
best_players.status_code
# Out:
# 200

# %%
best_pl = response.json()
df_players = pd.DataFrame(best_pl)

# %%
df_players
# Out:
#                                               shotmap
# 0   {'player': {'name': 'Jorge Cuenca', 'slug': 'j...
# 1   {'player': {'name': 'Ben Brereton Díaz', 'firs...
# 2   {'player': {'name': 'Fermín López', 'firstName...
# 3   {'player': {'name': 'Robert Lewandowski', 'fir...
# 4   {'player': {'name': 'Ansu Fati', 'slug': 'ansu...
# 5   {'player': {'name': 'Robert Lewandowski', 'fir...
# 6   {'player': {'name': 'Ansu Fati', 'slug': 'ansu...
# 7   {'player': {'name': 'Robert Lewandowski', 'fir...
# 8   {'player': {'name': 'Lamine Yamal', 'firstName...
# 9   {'player': {'name': 'Ferran Torres', 'slug': '...
# 10  {'player': {'name': 'Ferran Torres', 'slug': '...
# 11  {'player': {'name': 'Marcos Alonso', 'firstNam...
# 12  {'player': {'name': 'Robert Lewandowski', 'fir...
# 13  {'player': {'name': 'Lamine Yamal', 'firstName...
# 14  {'player': {'name': 'Juan Foyth', 'firstName':...
# 15  {'player': {'name': 'Alejandro Baena', 'firstN...
# 16  {'player': {'name': 'Oriol Romeu', 'firstName'...
# 17  {'player': {'name': 'Lamine Yamal', 'firstName...
# 18  {'player': {'name': 'Oriol Romeu', 'firstName'...
# 19  {'player': {'name': 'Alexander Sørloth', 'slug...
# 20  {'player': {'name': 'İlkay Gündoğan', 'slug': ...
# 21  {'player': {'name': 'Alejandro Baena', 'firstN...
# 22  {'player': {'name': 'Gerard Moreno', 'firstNam...
# 23  {'player': {'name': 'Juan Foyth', 'firstName':...
# 24  {'player': {'name': 'Alfonso Pedraza', 'firstN...
# 25  {'player': {'name': 'Robert Lewandowski', 'fir...
# 26  {'player': {'name': 'Frenkie de Jong', 'slug':...
# 27  {'player': {'name': 'Lamine Yamal', 'firstName...
# 28  {'player': {'name': 'Gavi', 'firstName': '', '...
# 29  {'player': {'name': 'Alexander Sørloth', 'slug...
# 30  {'player': {'name': 'Gerard Moreno', 'firstNam...
# 31  {'player': {'name': 'Alejandro Baena', 'firstN...
# 32  {'player': {'name': 'Alejandro Baena', 'firstN...
# 33  {'player': {'name': 'İlkay Gündoğan', 'slug': ...
